# %%
import pandas as pd
import numpy as np
import ta
import requests

def check_symbols_kline(symbol,interval,limit):
    url = f'https://contract.mexc.com/api/v1/contract/kline/{symbol}?interval={interval}&limit={limit}'

    response = requests.get(url)
    data = response.json()
                   
    df = pd.DataFrame(data['data'], columns=['time','open', 'low', 'high', 'close'])

    df.index = pd.to_datetime(df.time, unit='s', utc=True).map(lambda x: x.tz_convert('Asia/Hong_Kong'))

    #df.index = pd.to_datetime(df.index, unit='s')

    #df.set_index('time', inplace=True)


    return df

def check_symbols_with_increased_5d(percent,interval,limit):
    url = "https://contract.mexc.com/api/v1/contract/ticker"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        symbols = []
        x=1
        for ticker in data['data']:
            x=x+1
            if (x > 30):
                break
            symbol = ticker['symbol']
            try:
                df= check_symbols_kline(symbol,interval,limit)
                print(symbol)
                print(df)
                size=len(df)
                print(size)
                start_price = df['open'][0]
                end_price = df['close'][size-1]
                price_change = (end_price - start_price) / start_price * 100
                
                print(type(float(price_change)))
                print(type(percent))
                #line = [symbol, round(price_change_percentage*100,2)]
                if price_change > percent:
                    symbols.append(symbol)
            except Exception as error:
                print(symbol,error)               
                    
        symbols.sort(key=lambda element: element[0], reverse=False)

        return symbols
    else:
        print("Failed to retrieve data from MEXC API.")
        return None




def calculate_rsi(df, period=14):
    close_prices = df['close'].values
    rsi = ta.momentum.RSIIndicator(close_prices, n=period)
    rsi_values = rsi.rsi()
    return rsi_values

def calculate_macd(df, fast_period=12, slow_period=26, signal_period=9):
    close_prices = df['close'].values
    macd = ta.trend.MACD(close_prices, fast_period=fast_period, slow_period=slow_period, signal_period=signal_period)
    macd_values = macd.macd()
    signal_line = macd.macd_signal()
    return macd_values, signal_line

# Example usage
symbol = "BTC_USDT"
interval = "Day1"  # 1-hour candlestick data
limit=5
percent=20
# Fetch historical data using an API or from a CSV file
# Assuming you have OHLCV (Open, High, Low, Close, Volume) data
# stored in a pandas DataFrame named 'data'

# Assuming 'data' DataFrame has columns: ['timestamp', 'open', 'high', 'low', 'close', 'volume']
#data = check_symbols_kline(symbol, interval,limit)  # Replace this with your own data fetching logic

list=check_symbols_with_increased_5d(percent,interval,limit)
# Out:
# BTC_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  43896.4  43430.6  44470.3  43999.3
# 2023-12-23 08:00:00+08:00  1703289600  43999.3  43305.6  44021.9  43725.2
# 2023-12-24 08:00:00+08:00  1703376000  43725.2  42566.4  43992.7  43008.6
# 2023-12-25 08:00:00+08:00  1703462400  43008.6  42756.7  43850.3  43612.0
# 2023-12-26 08:00:00+08:00  1703548800  43612.0  42555.1  43632.5  42690.1
# 5
# <class 'float'>
# <class 'int'>
# ETH_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  2241.46  2232.58  2345.45  2326.53
# 2023-12-23 08:00:00+08:00  1703289600  2326.53  2266.62  2332.75  2310.41
# 2023-12-24 08:00:00+08:00  1703376000  2310.41  2242.87  2328.79  2265.43
# 2023-12-25 08:00:00+08:00  1703462400  2265.43  2254.39  2307.99  2273.09
# 2023-12-26 08:00:00+08:00  1703548800  2273.09  2220.40  2277.51  2239.08
# 5
# <class 'float'>
# <class 'int'>
# SOL_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200   93.915   90.514   99.604   97.954
# 2023-12-23 08:00:00+08:00  1703289600   97.954   92.900  110.371  107.939
# 2023-12-24 08:00:00+08:00  1703376000  107.939  107.350  118.322  112.618
# 2023-12-25 08:00:00+08:00  1703462400  112.618  108.016  126.927  120.954
# 2023-12-26 08:00:00+08:00  1703548800  120.954  110.847  121.437  114.039
# 5
# <class 'float'>
# <class 'int'>
# ORDI_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  52.893  50.180  54.846  52.092
# 2023-12-23 08:00:00+08:00  1703289600  52.092  48.057  54.034  51.377
# 2023-12-24 08:00:00+08:00  1703376000  51.377  50.120  58.136  52.270
# 2023-12-25 08:00:00+08:00  1703462400  52.270  51.507  78.180  75.383
# 2023-12-26 08:00:00+08:00  1703548800  75.383  64.820  83.185  69.776
# 5
# <class 'float'>
# <class 'int'>
# MOVR_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200   9.199   8.682  11.564   9.738
# 2023-12-23 08:00:00+08:00  1703289600   9.738   9.027  26.438  23.923
# 2023-12-24 08:00:00+08:00  1703376000  23.923  19.221  38.620  33.146
# 2023-12-25 08:00:00+08:00  1703462400  33.146  28.897  38.000  32.479
# 2023-12-26 08:00:00+08:00  1703548800  32.479  30.038  34.339  32.319
# 5
# <class 'float'>
# <class 'int'>
# XRP_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.6246  0.6157  0.6330  0.6250
# 2023-12-23 08:00:00+08:00  1703289600  0.6250  0.6110  0.6255  0.6201
# 2023-12-24 08:00:00+08:00  1703376000  0.6201  0.6026  0.6302  0.6128
# 2023-12-25 08:00:00+08:00  1703462400  0.6128  0.6088  0.6497  0.6468
# 2023-12-26 08:00:00+08:00  1703548800  0.6468  0.6186  0.6472  0.6234
# 5
# <class 'float'>
# <class 'int'>
# AVAX_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  46.018  43.731  48.970  45.358
# 2023-12-23 08:00:00+08:00  1703289600  45.358  43.376  48.349  48.114
# 2023-12-24 08:00:00+08:00  1703376000  48.114  46.394  50.030  47.733
# 2023-12-25 08:00:00+08:00  1703462400  47.733  46.003  48.987  48.242
# 2023-12-26 08:00:00+08:00  1703548800  48.242  45.167  48.403  46.339
# 5
# <class 'float'>
# <class 'int'>
# MATIC_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.8165  0.8125  0.8781  0.8781
# 2023-12-23 08:00:00+08:00  1703289600  0.8781  0.8280  0.8827  0.8584
# 2023-12-24 08:00:00+08:00  1703376000  0.8584  0.8310  0.8844  0.8478
# 2023-12-25 08:00:00+08:00  1703462400  0.8478  0.8362  0.9225  0.9127
# 2023-12-26 08:00:00+08:00  1703548800  0.9127  0.8619  0.9249  0.8716
# 5
# <class 'float'>
# <class 'int'>
# INJ_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  40.359  37.503  42.581  38.618
# 2023-12-23 08:00:00+08:00  1703289600  38.618  37.023  42.917  42.209
# 2023-12-24 08:00:00+08:00  1703376000  42.209  39.961  44.963  40.624
# 2023-12-25 08:00:00+08:00  1703462400  40.624  39.700  43.880  43.403
# 2023-12-26 08:00:00+08:00  1703548800  43.403  39.853  43.583  40.360
# 5
# <class 'float'>
# <class 'int'>
# JTO_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  2.8260  2.4508  2.9463  2.6029
# 2023-12-23 08:00:00+08:00  1703289600  2.6029  2.4873  2.6617  2.6326
# 2023-12-24 08:00:00+08:00  1703376000  2.6326  2.3550  2.7273  2.4482
# 2023-12-25 08:00:00+08:00  1703462400  2.4482  2.4206  2.9136  2.7528
# 2023-12-26 08:00:00+08:00  1703548800  2.7528  2.5727  2.8661  2.6214
# 5
# <class 'float'>
# <class 'int'>
# GROK_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.00690  0.00660  0.00869  0.00848
# 2023-12-23 08:00:00+08:00  1703289600  0.00848  0.00700  0.00869  0.00708
# 2023-12-24 08:00:00+08:00  1703376000  0.00708  0.00627  0.00737  0.00655
# 2023-12-25 08:00:00+08:00  1703462400  0.00655  0.00650  0.00728  0.00687
# 2023-12-26 08:00:00+08:00  1703548800  0.00687  0.00644  0.00718  0.00666
# 5
# <class 'float'>
# <class 'int'>
# AXS_USDT
#                                  time    open    low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200   7.583  7.311   7.665   7.631
# 2023-12-23 08:00:00+08:00  1703289600   7.631  7.322   7.724   7.684
# 2023-12-24 08:00:00+08:00  1703376000   7.684  7.604   9.478   9.130
# 2023-12-25 08:00:00+08:00  1703462400   9.130  8.773  11.138  10.226
# 2023-12-26 08:00:00+08:00  1703548800  10.226  9.655  10.693   9.716
# 5
# <class 'float'>
# <class 'int'>
# SATS_USDT
#                                  time          open           low  \
# time
# 2023-12-22 08:00:00+08:00  1703203200  7.071000e-07  6.215000e-07
# 2023-12-23 08:00:00+08:00  1703289600  6.495000e-07  5.944000e-07
# 2023-12-24 08:00:00+08:00  1703376000  6.334000e-07  5.960000e-07
# 2023-12-25 08:00:00+08:00  1703462400  6.204000e-07  6.140000e-07
# 2023-12-26 08:00:00+08:00  1703548800  8.600000e-07  7.702000e-07
#
#                                    high         close
# time
# 2023-12-22 08:00:00+08:00  7.142000e-07  6.495000e-07
# 2023-12-23 08:00:00+08:00  6.606000e-07  6.334000e-07
# 2023-12-24 08:00:00+08:00  6.692000e-07  6.204000e-07
# 2023-12-25 08:00:00+08:00  8.773000e-07  8.600000e-07
# 2023-12-26 08:00:00+08:00  9.314000e-07  8.155000e-07
# 5
# <class 'float'>
# <class 'int'>
# BAKE_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.3957  0.3793  0.4812  0.4525
# 2023-12-23 08:00:00+08:00  1703289600  0.4525  0.4168  0.5127  0.4248
# 2023-12-24 08:00:00+08:00  1703376000  0.4248  0.4246  0.7389  0.6688
# 2023-12-25 08:00:00+08:00  1703462400  0.6688  0.5760  0.7563  0.6599
# 2023-12-26 08:00:00+08:00  1703548800  0.6599  0.6563  0.7492  0.6807
# 5
# <class 'float'>
# <class 'int'>
# OP_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  2.5236  2.4947  3.5490  3.4690
# 2023-12-23 08:00:00+08:00  1703289600  3.4690  3.1117  3.5383  3.4491
# 2023-12-24 08:00:00+08:00  1703376000  3.4491  3.3147  3.8484  3.5687
# 2023-12-25 08:00:00+08:00  1703462400  3.5687  3.3563  3.7428  3.3747
# 2023-12-26 08:00:00+08:00  1703548800  3.3747  3.2190  3.5017  3.2779
# 5
# <class 'float'>
# <class 'int'>
# WLD_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  3.5309  3.4574  3.7698  3.6939
# 2023-12-23 08:00:00+08:00  1703289600  3.6939  3.3349  3.7439  3.4615
# 2023-12-24 08:00:00+08:00  1703376000  3.4615  3.2694  3.5950  3.3637
# 2023-12-25 08:00:00+08:00  1703462400  3.3637  3.3637  3.7822  3.7661
# 2023-12-26 08:00:00+08:00  1703548800  3.7661  3.6672  4.0817  3.7054
# 5
# <class 'float'>
# <class 'int'>
# 1000RATS_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.33468  0.28500  0.34200  0.31003
# 2023-12-23 08:00:00+08:00  1703289600  0.31003  0.29030  0.34058  0.32437
# 2023-12-24 08:00:00+08:00  1703376000  0.32437  0.30027  0.34150  0.31515
# 2023-12-25 08:00:00+08:00  1703462400  0.31515  0.31227  0.45100  0.41503
# 2023-12-26 08:00:00+08:00  1703548800  0.41503  0.37000  0.45362  0.39150
# 5
# <class 'float'>
# <class 'int'>
# GALA_USDT
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.03146  0.03109  0.03286  0.03225
# 2023-12-23 08:00:00+08:00  1703289600  0.03225  0.03070  0.03245  0.03156
# 2023-12-24 08:00:00+08:00  1703376000  0.03156  0.03012  0.03232  0.03097
# 2023-12-25 08:00:00+08:00  1703462400  0.03097  0.03024  0.03676  0.03574
# 2023-12-26 08:00:00+08:00  1703548800  0.03574  0.03295  0.03646  0.03323
# 5
# <class 'float'>
# <class 'int'>
# ADA_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.6358  0.6064  0.6521  0.6229
# 2023-12-23 08:00:00+08:00  1703289600  0.6229  0.5967  0.6234  0.6135
# 2023-12-24 08:00:00+08:00  1703376000  0.6135  0.5839  0.6292  0.5923
# 2023-12-25 08:00:00+08:00  1703462400  0.5923  0.5895  0.6362  0.6249
# 2023-12-26 08:00:00+08:00  1703548800  0.6249  0.5943  0.6286  0.6070
# 5
# <class 'float'>
# <class 'int'>
# NEAR_USDT
#                                  time   open    low   high  close
# time
# 2023-12-22 08:00:00+08:00  1703203200  3.540  3.277  3.810  3.361
# 2023-12-23 08:00:00+08:00  1703289600  3.361  3.208  3.985  3.907
# 2023-12-24 08:00:00+08:00  1703376000  3.907  3.611  4.104  3.803
# 2023-12-25 08:00:00+08:00  1703462400  3.803  3.726  4.387  4.254
# 2023-12-26 08:00:00+08:00  1703548800  4.254  4.127  4.547  4.422
# 5
# <class 'float'>
# <class 'int'>
# BTC_USD
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  43901.0  43444.4  44472.3  44030.8
# 2023-12-23 08:00:00+08:00  1703289600  44030.8  43339.5  44046.9  43747.0
# 2023-12-24 08:00:00+08:00  1703376000  43747.0  42551.9  44005.8  43050.5
# 2023-12-25 08:00:00+08:00  1703462400  43050.5  42783.3  43859.8  43624.1
# 2023-12-26 08:00:00+08:00  1703548800  43624.1  42573.1  43650.3  42693.4
# 5
# <class 'float'>
# <class 'int'>
# TIA_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  12.887  11.758  13.356  12.405
# 2023-12-23 08:00:00+08:00  1703289600  12.405  11.596  12.439  12.281
# 2023-12-24 08:00:00+08:00  1703376000  12.281  11.969  15.280  14.154
# 2023-12-25 08:00:00+08:00  1703462400  14.154  13.502  14.760  13.741
# 2023-12-26 08:00:00+08:00  1703548800  13.741  13.100  14.050  13.210
# 5
# <class 'float'>
# <class 'int'>
# ETH_USD
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  2241.31  2233.17  2346.27  2328.20
# 2023-12-23 08:00:00+08:00  1703289600  2328.20  2268.76  2334.11  2311.30
# 2023-12-24 08:00:00+08:00  1703376000  2311.30  2245.01  2330.00  2265.94
# 2023-12-25 08:00:00+08:00  1703462400  2265.94  2255.39  2308.29  2273.57
# 2023-12-26 08:00:00+08:00  1703548800  2273.57  2221.50  2277.76  2238.84
# 5
# <class 'float'>
# <class 'int'>
# SUI_USDT
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.6888  0.6569  0.7017  0.6958
# 2023-12-23 08:00:00+08:00  1703289600  0.6958  0.6930  0.7591  0.7544
# 2023-12-24 08:00:00+08:00  1703376000  0.7544  0.7023  0.7619  0.7143
# 2023-12-25 08:00:00+08:00  1703462400  0.7143  0.7114  0.8301  0.8177
# 2023-12-26 08:00:00+08:00  1703548800  0.8177  0.8063  0.8888  0.8468
# 5
# <class 'float'>
# <class 'int'>
# APT_USDT
#                                  time    open    low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200   8.527  8.309   9.439   9.268
# 2023-12-23 08:00:00+08:00  1703289600   9.268  8.998  10.154   9.317
# 2023-12-24 08:00:00+08:00  1703376000   9.317  9.040   9.900   9.319
# 2023-12-25 08:00:00+08:00  1703462400   9.319  9.137  10.693  10.422
# 2023-12-26 08:00:00+08:00  1703548800  10.422  9.960  10.575  10.150
# 5
# <class 'float'>
# <class 'int'>
# XRP_USD
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.6246  0.6157  0.6327  0.6253
# 2023-12-23 08:00:00+08:00  1703289600  0.6253  0.6115  0.6258  0.6201
# 2023-12-24 08:00:00+08:00  1703376000  0.6201  0.6052  0.6305  0.6129
# 2023-12-25 08:00:00+08:00  1703462400  0.6129  0.6093  0.6496  0.6467
# 2023-12-26 08:00:00+08:00  1703548800  0.6467  0.6188  0.6472  0.6234
# 5
# <class 'float'>
# <class 'int'>
# ADA_USD
#                                  time    open     low    high   close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.6358  0.6069  0.6523  0.6235
# 2023-12-23 08:00:00+08:00  1703289600  0.6235  0.5980  0.6239  0.6137
# 2023-12-24 08:00:00+08:00  1703376000  0.6137  0.5865  0.6294  0.5926
# 2023-12-25 08:00:00+08:00  1703462400  0.5926  0.5900  0.6363  0.6251
# 2023-12-26 08:00:00+08:00  1703548800  0.6251  0.5947  0.6289  0.6069
# 5
# <class 'float'>
# <class 'int'>
# XLM_USD
#                                  time     open      low     high    close
# time
# 2023-12-22 08:00:00+08:00  1703203200  0.12478  0.12327  0.12686  0.12681
# 2023-12-23 08:00:00+08:00  1703289600  0.12681  0.12388  0.12722  0.12677
# 2023-12-24 08:00:00+08:00  1703376000  0.12677  0.12450  0.12810  0.12604
# 2023-12-25 08:00:00+08:00  1703462400  0.12604  0.12524  0.13181  0.13125
# 2023-12-26 08:00:00+08:00  1703548800  0.13125  0.12586  0.13136  0.12741
# 5
# <class 'float'>
# <class 'int'>
# BOND_USDT
#                                  time   open    low   high  close
# time
# 2023-12-22 08:00:00+08:00  1703203200  3.753  3.618  3.938  3.885
# 2023-12-23 08:00:00+08:00  1703289600  3.885  3.706  3.902  3.885
# 2023-12-24 08:00:00+08:00  1703376000  3.885  3.798  7.284  6.844
# 2023-12-25 08:00:00+08:00  1703462400  6.844  5.034  8.206  5.464
# 2023-12-26 08:00:00+08:00  1703548800  5.464  5.122  5.810  5.146
# 5
# <class 'float'>
# <class 'int'>

# %%
list
# Out:
# ['1000BONK_USDT',
#  'FTT_USDT',
#  'HIFI_USDT',
#  'KAS_USDT',
#  'LUNANEW_USDT',
#  'ORDI_USDT',
#  'SOL_USDT',
#  'STORJ_USDT',
#  'TIA_USDT']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 type(price_change)
#
# NameError: name 'price_change' is not defined

# %%
df = pd.DataFrame(list)

# %%
df
# Out:
#             0
# 0   API3_USDT
# 1   BLUR_USDT
# 2   CAKE_USDT
# 3    GAS_USDT
# 4    GRT_USDT
# 5    INJ_USDT
# 6   LINK_USDT
# 7   ORDI_USDT
# 8    TRB_USDT
# 9    TWT_USDT
# 10  UNFI_USDT
# 11   XRP_USDT
# 12    XRP_USD

# %%
data = check_symbols_kline('CELR_USDT', interval,limit)  # Replace this with your own data fetching logic

# %%
data
# Out:
#                                  time     open      low     high    close
# time
# 2023-10-07 08:00:00+08:00  1696636800  0.01248  0.01240  0.01261  0.01255
# 2023-10-08 08:00:00+08:00  1696723200  0.01255  0.01237  0.01266  0.01251
# 2023-10-09 08:00:00+08:00  1696809600  0.01251  0.01141  0.01260  0.01189
# 2023-10-10 08:00:00+08:00  1696896000  0.01189  0.01154  0.01195  0.01162
# 2023-10-11 08:00:00+08:00  1696982400  0.01162  0.01136  0.01170  0.01152

# %%
price_change
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 price_change
#
# NameError: name 'price_change' is not defined
